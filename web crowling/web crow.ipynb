# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup


html = urlopen("https://www.wikipedia.org/")
bsobject = BeautifulSoup(html.read(),"html.parser")
print(bsobject.h1)
# Out:
# <h1 class="central-textlogo" style="font-size: 1em;" title="Wikipedia">
# <img alt="Wikipedia" class="central-featured-logo" height="183" src="portal/wikipedia.org/assets/img/Wikipedia-logo-v2.png" srcset="portal/wikipedia.org/assets/img/Wikipedia-logo-v2@1.5x.png 1.5x, portal/wikipedia.org/assets/img/Wikipedia-logo-v2@2x.png 2x" width="200"/>
# <div class="central-textlogo-wrapper">
# <div class="central-textlogo__image sprite svg-Wikipedia_wordmark">
# Wikipedia
# </div>
# <strong class="jsl10n localized-slogan" data-jsl10n="slogan">The Free Encyclopedia</strong>
# </div>
# </h1>

# %%
from urllib.request import urlopen

html = urlopen("https://www.linkedin.com/feed/followers/")

print(html.read())
# Out:
# b' <!DOCTYPE html>\n<html lang="en">\n  <head>\n    <script type="application/javascript">!function(i,n){void 0!==i.addEventListener&&void 0!==i.hidden&&(n.liVisibilityChangeListener=function(){i.hidden&&(n.liHasWindowHidden=!0)},i.addEventListener("visibilitychange",n.liVisibilityChangeListener))}(document,window);</script>\n\n    <meta charset="utf-8">\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\n    <title>LinkedIn</title>\n    <meta name="description" content="">\n    <meta name="viewport" content="width=device-width, initial-scale=1.0, minimum-scale=1.0">\n    <meta name="theme-color" content="#0077B5">\n    <meta name="is-http2" content="false">\n\n    <link rel="manifest" href="/voyager/manifest.json">\n\n    \n<meta name="extended/config/environment" content="%7B%22modulePrefix%22%3A%22extended%22%2C%22environment%22%3A%22production%22%2C%22ember-a11y-testing%22%3A%7B%22componentOptions%22%3A%7B%22turnAuditOff%22%3Atrue%7D%7D%2C%22lix%22%3A%7B%22lixKeys%22%3A%5
# ...
